# %%
import twitter

CONSUMER_KEY = 'duGSyjqQmC3AalurtgQyukgpl'
CONSUMER_SECRET = 'Tc6pwlVJwxIN4XPMC4iiSG36QqGnxhoS5gCBFdiPoQIwtJQXbm'
OAUTH_TOKEN = '1292848789628301321-SbMsWQdef3oUbW2V4IsSaIcvrW6Li1'
OAUTH_TOKEN_SECRET = '2htChhUteurnuzw6BUxGbK6vi93Z07zo1zwisTwHUY8ZZ'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x000002649B794DF0>

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977
CH_WOE_ID = 23424957

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
swiss_trends = twitter_api.trends.place(_id=CH_WOE_ID) 

print(world_trends)
print(us_trends)
# Out:
# [{'trends': [{'name': '天気の子', 'url': 'http://twitter.com/search?q=%E5%A4%A9%E6%B0%97%E3%81%AE%E5%AD%90', 'promoted_content': None, 'query': '%E5%A4%A9%E6%B0%97%E3%81%AE%E5%AD%90', 'tweet_volume': 80485}, {'name': '#VS魂', 'url': 'http://twitter.com/search?q=%23VS%E9%AD%82', 'promoted_content': None, 'query': '%23VS%E9%AD%82', 'tweet_volume': 196623}, {'name': '#麒麟がくる', 'url': 'http://twitter.com/search?q=%23%E9%BA%92%E9%BA%9F%E3%81%8C%E3%81%8F%E3%82%8B', 'promoted_content': None, 'query': '%23%E9%BA%92%E9%BA%9F%E3%81%8C%E3%81%8F%E3%82%8B', 'tweet_volume': 63453}, {'name': '#あなたっぽいおもち', 'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%A3%E3%81%BD%E3%81%84%E3%81%8A%E3%82%82%E3%81%A1', 'promoted_content': None, 'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%A3%E3%81%BD%E3%81%84%E3%81%8A%E3%82%82%E3%81%A1', 'tweet_volume': 37406}, {'name': '#marr', 'url': 'http://twitter.com/search?q=%23marr', 'promoted_content': None, 'query': '%23marr', 'tweet_volume': 53032}, {'name': '#イッテQ', 'url': 'http://twitter.com/search?q=%23%E3%82%A4%E3%83%83%E3%83%86Q', 'promoted_content': None, 'query': '%23%E3%82%A4%E3%83%83%E3%83%86Q', 'tweet_volume': 28419}, {'name': '謎の安心感', 'url': 'http://twitter.com/search?q=%E8%AC%8E%E3%81%AE%E5%AE%89%E5%BF%83%E6%84%9F', 'promoted_content': None, 'query': '%E8%AC%8E%E3%81%AE%E5%AE%89%E5%BF%83%E6%84%9F', 'tweet_volume': 12208}, {'name': 'キムタくん', 'url': 'http://twitter.com/search?q=%E3%82%AD%E3%83%A0%E3%82%BF%E3%81%8F%E3%82%93', 'promoted_content': None, 'query': '%E3%82%AD%E3%83%A0%E3%82%BF%E3%81%8F%E3%82%93', 'tweet_volume': 13764}, {'name': 'DAMASHI魂', 'url': 'http://twitter.com/search?q=DAMASHI%E9%AD%82', 'promoted_content': None, 'query': 'DAMASHI%E9%AD%82', 'tweet_volume': 11184}, {'name': 'SHEHNAAZs BDAY MONTH', 'url': 'http://twitter.com/search?q=%22SHEHNAAZs+BDAY+MONTH%22', 'promoted_content': None, 'query': '%22SHEHNAAZs+BDAY+MONTH%22
sunday+of+2021%22', 'tweet_volume': 15453}, {'name': 'Romney', 'url': 'http://twitter.com/search?q=Romney', 'promoted_content': None, 'query': 'Romney', 'tweet_volume': 162224}, {'name': 'zeek', 'url': 'http://twitter.com/search?q=zeek', 'promoted_content': None, 'query': 'zeek', 'tweet_volume': None}, {'name': 'Tommie', 'url': 'http://twitter.com/search?q=Tommie', 'promoted_content': None, 'query': 'Tommie', 'tweet_volume': None}, {'name': 'Peter Navarro', 'url': 'http://twitter.com/search?q=%22Peter+Navarro%22', 'promoted_content': None, 'query': '%22Peter+Navarro%22', 'tweet_volume': 23262}, {'name': 'cafe 101', 'url': 'http://twitter.com/search?q=%22cafe+101%22', 'promoted_content': None, 'q ...

# %%
for trend in world_trends[0]['trends']:
    print(trend['name'])
# Out:
# 天気の子
# #VS魂
# #麒麟がくる
# #あなたっぽいおもち
# #marr
# #イッテQ
# 謎の安心感
# キムタくん
# DAMASHI魂
# Vidal
# SHEHNAAZs BDAY MONTH
# 紫耀くん
# 자캐 만들기
# 浮所くん
# オタク気質
# おもちタイプ
# レギュラー
# 教場II
# きな粉餅
# 砂糖醤油
# 雑煮の人と相性抜群
# 相葉くん
# BOV 1ST REVEAL
# キティさん
# あんころ餅の人と相性抜群
# 風間ぽん
# 力うどんの人と相性抜群
# からみ餅の人と相性抜群
# YSSB
# 相葉ちゃん
# チャオチャオ
# Dekolte YasakDeğil
# 磯辺焼きの人と相性抜群
# Schnee
# 勝利くん
# Engellinin SesiDuyulsun
# しるこの人と相性抜群
# Tariq
# 알파 오메가
# 다음 커뮤
# キムタク
# 페로몬 포함
# Hakan Altun
# 風間くん
# 人の心の機微
# 浅倉大介
# HalıSahalar Açılsın
# 平野くん
# 団体行動
# 🙃2021

# %%
for trend in swiss_trends[0]['trends']:
    print(trend['name'])
# Out:
# #WirMachenAuf
# Kamera
# Lage
# Shutdown
# Impfdosen
# Regierungen
# #SwissCovidFail
# Bundesrat
# Impfen
# Steuern
# Wissenschaft
# Parmelin
# Buona
# Handeln
# Lockdowns
# Impfstoff
# Massnahmen
# Behörden
# Bericht
# #CoronaInfoCH
# #Impfung
# Quellen
# Licht
# Bevölkerung
# La Suisse
# #B117
# Möglichkeiten
# Schaden
# Strategie
# Ausland
# Stimme
# Worten
# Schulen
# Verständnis
# Brot
# kantone
# fallzahlen
# Körper
# Tests
# Linie
# Trump
# Lösung
# Grippe
# Kontext
# Vergleich
# Liste
# Monaten
# Biden
# Aussagen
# Konsequenzen

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

swiss_trends = set([trend['name'] 
                     for trend in swiss_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(swiss_trends)

print(common_trends)
# Out:
# set()

# %%
import json

# Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = '#MothersDay' 

count = 100

# Import unquote to prevent url encoding errors in next_results
from urllib.parse import unquote

# See https://dev.twitter.com/rest/reference/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor
for _ in range(5):
    print('Length of statuses', len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError as e: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=847960489447628799&q=%23RIPSelena&count=100&include_entities=1
    kwargs = dict([ kv.split('=') for kv in unquote(next_results[1:]).split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# Length of statuses 100
# Length of statuses 200
# Length of statuses 300
# Length of statuses 400
# Length of statuses 500
# {
#  "created_at": "Sun Jan 03 12:18:02 +0000 2021",
#  "id": 1345705981150449666,
#  "id_str": "1345705981150449666",
#  "text": "#Music Lovers Rejoice #ModernQuilt #Giftforhim #GiftsforTeens #Giftsforher #Minky #Quilt What a great #Wedding,\u2026 https://t.co/HBn67SkMXJ",
#  "truncated": true,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "Music",
#     "indices": [
#      0,
#      6
#     ]
#    },
#    {
#     "text": "ModernQuilt",
#     "indices": [
#      22,
#      34
#     ]
#    },
#    {
#     "text": "Giftforhim",
#     "indices": [
#      35,
#      46
#     ]
#    },
#    {
#     "text": "GiftsforTeens",
#     "indices": [
#      47,
#      61
#     ]
#    },
#    {
#     "text": "Giftsforher",
#     "indices": [
#      62,
#      74
#     ]
#    },
#    {
#     "text": "Minky",
#     "indices": [
#      75,
#      81
#     ]
#    },
#    {
#     "text": "Quilt",
#     "indices": [
#      82,
#      88
#     ]
#    },
#    {
#     "text": "Wedding",
#     "indices": [
#      102,
#      110
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [],
#   "urls": [
#    {
#     "url": "https://t.co/HBn67SkMXJ",
#     "expanded_url": "https://twitter.com/i/web/status/1345705981150449666",
#     "display_url": "twitter.com/i/web/status/1\u2026",
#     "indices": [
#      113,
#      136
#     ]
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"https://buffer.com\" rel=\"nofollow\">Buffer</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 4578320954,
#   "id_str": "4578320954",
#   "name": "\ud83d\udc96Stephanie Howarth",
#   "screen_name": "howarths63",
#   "location": "Roseville, CA",
#   "description": "Maker of high Quality Handmade Quilts for all ages as well as one of a kind baby items!  I RT & follow those who RT others.",
#   "url": "https://t.co/UAS86U9Mxi",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/UAS86U9Mxi",
#       "expanded_url": "https://www.etsy.com/shop/SewStephWA?ref=hdr_shop_menu",
#       "display_url": "etsy.com/shop/SewStephW\u2026",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 12161,
#   "friends_count": 4486,
#   "listed_count": 833,
#   "created_at": "Wed Dec 16 20:55:04 +0000 2015",
#   "favourites_count": 2329,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 176818,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "000000",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme4/bg.gif",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme4/bg.gif",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1301988975930781701/TakX5s1x_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1301988975930781701/TakX5s1x_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/4578320954/1498062987",
#   "profile_link_color": "3333FF",
#   "profile_sidebar_border_color": "000000",
#   "profile_sidebar_fill_color": "000000",
#   "profile_text_color": "000000",
#   "profile_use_background_image": false,
#   "has_extended_profile": true,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "is_quote_status": false,
#  "retweet_count": 0,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "en"
# }

# %%
for i in range(10):
    print()
    print(statuses[i]['text'])
    print('Favorites: ', statuses[i]['favorite_count'])
    print('Retweets: ', statuses[i]['retweet_count'])
# Out:
# #Music Lovers Rejoice #ModernQuilt #Giftforhim #GiftsforTeens #Giftsforher #Minky #Quilt What a great #Wedding,… https://t.co/HBn67SkMXJ
# Favorites:  0
# Retweets:  0
#
# RT @Shahbaz_Nadir2: Love you Mom Always ❤️
# “To the world you are a Mother, but to your family you are the World"
# This Picture will Expresse…
# Favorites:  0
# Retweets:  3160
#
# https://t.co/bAdgnfoHJr
# #brooch #vintage #potMetal #artDeco #glass #purple #rhinestones #silverTone #leaves #stems… https://t.co/igb1rYipPs
# Favorites:  0
# Retweets:  0
#
# RT @sonymusicde: Happy #Muttertag! 🍰💐
#
#  🎵"I ain't gon' be cooking all day, I ain't your mama."🎵 @JLo #MothersDay #HappyMothersDay https://t…
# Favorites:  0
# Retweets:  25
#
# #GraphicTShirt #paleyellow #tulips #abstract #acrylicpainting #impressionism #expressionism #flower #tulpen… https://t.co/pMJHkhSDRt
# Favorites:  0
# Retweets:  0
#
# RT @Shahbaz_Nadir2: Love you Mom Always ❤️
# “To the world you are a Mother, but to your family you are the World"
# This Picture will Expresse…
# Favorites:  0
# Retweets:  3160
#
# RT @o___8: Happy Mother's Day ! #MothersDay #mothersday2020  #FF7 #Sephiroth #jenova https://t.co/bntlH4lCz8
# Favorites:  0
# Retweets:  1487
#
# RT @Shahbaz_Nadir2: Love you Mom Always ❤️
# “To the world you are a Mother, but to your family you are the World"
# This Picture will Expresse…
# Favorites:  0
# Retweets:  3160
#
# RT @Shahbaz_Nadir2: Love you Mom Always ❤️
# “To the world you are a Mother, but to your family you are the World"
# This Picture will Expresse…
# Favorites:  0
# Retweets:  3160
#
# RT @flwrgardengifts: Smiles will be popping from a distance with this Gnome Door Wreath 😉
#
# #wreath #wreathsofinstagram #gnome #happiness #C…
# Favorites:  0
# Retweets:  3926

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1) )
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "#Music Lovers Rejoice #ModernQuilt #Giftforhim #GiftsforTeens #Giftsforher #Minky #Quilt What a great #Wedding,\u2026 https://t.co/HBn67SkMXJ",
#  "RT @Shahbaz_Nadir2: Love you Mom Always \u2764\ufe0f\n\u201cTo the world you are a Mother, but to your family you are the World\"\nThis Picture will Expresse\u2026",
#  "https://t.co/bAdgnfoHJr \n#brooch #vintage #potMetal #artDeco #glass #purple #rhinestones #silverTone #leaves #stems\u2026 https://t.co/igb1rYipPs",
#  "RT @sonymusicde: Happy #Muttertag! \ud83c\udf70\ud83d\udc90\n\n \ud83c\udfb5\"I ain't gon' be cooking all day, I ain't your mama.\"\ud83c\udfb5 @JLo #MothersDay #HappyMothersDay https://t\u2026",
#  "#GraphicTShirt #paleyellow #tulips #abstract #acrylicpainting #impressionism #expressionism #flower #tulpen\u2026 https://t.co/pMJHkhSDRt"
# ]
# [
#  "Shahbaz_Nadir2",
#  "sonymusicde",
#  "JLo",
#  "Shahbaz_Nadir2",
#  "o___8"
# ]
# [
#  "Music",
#  "ModernQuilt",
#  "Giftforhim",
#  "GiftsforTeens",
#  "Giftsforher"
# ]
# [
#  "#Music",
#  "Lovers",
#  "Rejoice",
#  "#ModernQuilt",
#  "#Giftforhim"
# ]

# %%
import matplotlib.pyplot as plt
from collections import Counter
# %matplotlib inline
word_counts = sorted(Counter(words).values(), reverse=True)

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")

for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data
    # and plot the values
    c = Counter(data)
    plt.hist(list(c.values()))
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.figure()

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1) )
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "#Music Lovers Rejoice #ModernQuilt #Giftforhim #GiftsforTeens #Giftsforher #Minky #Quilt What a great #Wedding,\u2026 https://t.co/HBn67SkMXJ",
#  "RT @Shahbaz_Nadir2: Love you Mom Always \u2764\ufe0f\n\u201cTo the world you are a Mother, but to your family you are the World\"\nThis Picture will Expresse\u2026",
#  "https://t.co/bAdgnfoHJr \n#brooch #vintage #potMetal #artDeco #glass #purple #rhinestones #silverTone #leaves #stems\u2026 https://t.co/igb1rYipPs",
#  "RT @sonymusicde: Happy #Muttertag! \ud83c\udf70\ud83d\udc90\n\n \ud83c\udfb5\"I ain't gon' be cooking all day, I ain't your mama.\"\ud83c\udfb5 @JLo #MothersDay #HappyMothersDay https://t\u2026",
#  "#GraphicTShirt #paleyellow #tulips #abstract #acrylicpainting #impressionism #expressionism #flower #tulpen\u2026 https://t.co/pMJHkhSDRt"
# ]
# [
#  "Shahbaz_Nadir2",
#  "sonymusicde",
#  "JLo",
#  "Shahbaz_Nadir2",
#  "o___8"
# ]
# [
#  "Music",
#  "ModernQuilt",
#  "Giftforhim",
#  "GiftsforTeens",
#  "Giftsforher"
# ]
# [
#  "#Music",
#  "Lovers",
#  "Rejoice",
#  "#ModernQuilt",
#  "#Giftforhim"
# ]

# %%
def twitter_search(twitter_api, q, max_results=200, **kw):
    # See https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
    # and https://developer.twitter.com/en/docs/tweets/search/guides/standard-operators
    # for details on advanced search criteria that may be useful for 
    # keyword arguments
    
    # See https://dev.twitter.com/docs/api/1.1/get/search/tweets    
    search_results = twitter_api.search.tweets(q=q, count=100, **kw)
    
    statuses = search_results['statuses']
    
    # Iterate through batches of results by following the cursor until we
    # reach the desired number of results, keeping in mind that OAuth users
    # can "only" make 180 search queries per 15-minute interval. See
    # https://developer.twitter.com/en/docs/basics/rate-limits
    # for details. A reasonable number of results is ~1000, although
    # that number of results may not exist for all queries.
    
    # Enforce a reasonable limit
    max_results = min(1000, max_results)
    
    for _ in range(10): # 10*100 = 1000
        try:
            next_results = search_results['search_metadata']['next_results']
        except KeyError as e: # No more results when next_results doesn't exist
            break
            
        # Create a dictionary from next_results, which has the following form:
        # ?max_id=313519052523986943&q=NCAA&include_entities=1
        kwargs = dict([ kv.split('=') 
                        for kv in next_results[1:].split("&") ])
        
        search_results = twitter_api.search.tweets(**kwargs)
        statuses += search_results['statuses']
        
        if len(statuses) > max_results: 
            break
            
    return statuses
q = "#WirMachenAuf"
results = twitter_search(twitter_api, q, max_results=10)
        
# Show one sample search result by slicing the list...
    
print(json.dumps(results[1], indent=1))
# Out:
# {
#  "created_at": "Sun Jan 03 12:34:39 +0000 2021",
#  "id": 1345710164620546049,
#  "id_str": "1345710164620546049",
#  "text": "RT @Bartlinux: #WirMachenAuf https://t.co/XVBi7BUk1l",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "WirMachenAuf",
#     "indices": [
#      15,
#      28
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "Bartlinux",
#     "name": "Mensch, MdB",
#     "id": 15252968,
#     "id_str": "15252968",
#     "indices": [
#      3,
#      13
#     ]
#    }
#   ],
#   "urls": [],
#   "media": [
#    {
#     "id": 1345629152855142400,
#     "id_str": "1345629152855142400",
#     "indices": [
#      29,
#      52
#     ],
#     "media_url": "http://pbs.twimg.com/media/EqyilcdXMAAcJ2B.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/EqyilcdXMAAcJ2B.jpg",
#     "url": "https://t.co/XVBi7BUk1l",
#     "display_url": "pic.twitter.com/XVBi7BUk1l",
#     "expanded_url": "https://twitter.com/Bartlinux/status/1345629155958943744/photo/1",
#     "type": "photo",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "small": {
#       "w": 583,
#       "h": 329,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 583,
#       "h": 329,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 583,
#       "h": 329,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 1345629155958943744,
#     "source_status_id_str": "1345629155958943744",
#     "source_user_id": 15252968,
#     "source_user_id_str": "15252968"
#    }
#   ]
#  },
#  "extended_entities": {
#   "media": [
#    {
#     "id": 1345629152855142400,
#     "id_str": "1345629152855142400",
#     "indices": [
#      29,
#      52
#     ],
#     "media_url": "http://pbs.twimg.com/media/EqyilcdXMAAcJ2B.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/EqyilcdXMAAcJ2B.jpg",
#     "url": "https://t.co/XVBi7BUk1l",
#     "display_url": "pic.twitter.com/XVBi7BUk1l",
#     "expanded_url": "https://twitter.com/Bartlinux/status/1345629155958943744/photo/1",
#     "type": "photo",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "small": {
#       "w": 583,
#       "h": 329,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 583,
#       "h": 329,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 583,
#       "h": 329,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 1345629155958943744,
#     "source_status_id_str": "1345629155958943744",
#     "source_user_id": 15252968,
#     "source_user_id_str": "15252968"
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "und",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 2673700208,
#   "id_str": "2673700208",
#   "name": "Jay",
#   "screen_name": "Kawkas24",
#   "location": "Nds.Germany",
#   "description": "Mag weder Rassisten noch Faschisten.F\u00fcr Anstand,Fairness,Toleranz,Klimaschutz&einen guten Umgangston.Mein \u2764 schl\u00e4gt Links#TeamDrosten\ud83c\udf0d\ud83c\udf08\ud83c\udf0a",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 968,
#   "friends_count": 803,
#   "listed_count": 2,
#   "created_at": "Wed Jul 23 12:39:04 +0000 2014",
#   "favourites_count": 111112,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 22865,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "000000",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1343051223142961152/FNmFnGBo_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1343051223142961152/FNmFnGBo_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/2673700208/1608203311",
#   "profile_link_color": "ABB8C2",
#   "profile_sidebar_border_color": "000000",
#   "profile_sidebar_fill_color": "000000",
#   "profile_text_color": "000000",
#   "profile_use_background_image": false,
#   "has_extended_profile": true,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Sun Jan 03 07:12:46 +0000 2021",
#   "id": 1345629155958943744,
#   "id_str": "1345629155958943744",
#   "text": "#WirMachenAuf https://t.co/XVBi7BUk1l",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "WirMachenAuf",
#      "indices": [
#       0,
#       13
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [],
#    "media": [
#     {
#      "id": 1345629152855142400,
#      "id_str": "1345629152855142400",
#      "indices": [
#       14,
#       37
#      ],
#      "media_url": "http://pbs.twimg.com/media/EqyilcdXMAAcJ2B.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/EqyilcdXMAAcJ2B.jpg",
#      "url": "https://t.co/XVBi7BUk1l",
#      "display_url": "pic.twitter.com/XVBi7BUk1l",
#      "expanded_url": "https://twitter.com/Bartlinux/status/1345629155958943744/photo/1",
#      "type": "photo",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "small": {
#        "w": 583,
#        "h": 329,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 583,
#        "h": 329,
#        "resize": "fit"
#       },
#       "medium": {
#        "w": 583,
#        "h": 329,
#        "resize": "fit"
#       }
#      }
#     }
#    ]
#   },
#   "extended_entities": {
#    "media": [
#     {
#      "id": 1345629152855142400,
#      "id_str": "1345629152855142400",
#      "indices": [
#       14,
#       37
#      ],
#      "media_url": "http://pbs.twimg.com/media/EqyilcdXMAAcJ2B.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/EqyilcdXMAAcJ2B.jpg",
#      "url": "https://t.co/XVBi7BUk1l",
#      "display_url": "pic.twitter.com/XVBi7BUk1l",
#      "expanded_url": "https://twitter.com/Bartlinux/status/1345629155958943744/photo/1",
#      "type": "photo",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "small": {
#        "w": 583,
#        "h": 329,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 583,
#        "h": 329,
#        "resize": "fit"
#       },
#       "medium": {
#        "w": 583,
#        "h": 329,
#        "resize": "fit"
#       }
#      }
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "und",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 15252968,
#    "id_str": "15252968",
#    "name": "Mensch, MdB",
#    "screen_name": "Bartlinux",
#    "location": "Schweiz",
#    "description": "Mensch. Antifa! Header von @jaxxon2905 @sch1ld3r5 @alex_mir_doch \ud83d\ude18",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 3454,
#    "friends_count": 4900,
#    "listed_count": 51,
#    "created_at": "Fri Jun 27 07:58:21 +0000 2008",
#    "favourites_count": 53649,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 38581,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "352726",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme5/bg.gif",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme5/bg.gif",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1331737958219718659/YNDGN5Ml_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1331737958219718659/YNDGN5Ml_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/15252968/1606139007",
#    "profile_link_color": "D02B55",
#    "profile_sidebar_border_color": "829D5E",
#    "profile_sidebar_fill_color": "99CC33",
#    "profile_text_color": "3E4415",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 4,
#   "favorite_count": 20,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "und"
#  },
#  "is_quote_status": false,
#  "retweet_count": 4,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "und"
# }

# %%
import tweepy
import json
import time
import datetime
import os
import csv

def initiate_api():
    try: 
        with open('config.json', 'r') as f:
            config = json.load(f)        
        auth = tweepy.OAuthHandler(config["CONSUMER_KEY"], config["CONSUMER_SECRET"])
        auth.set_access_token(config["ACCESS_KEY"], config["ACCESS_SECRET"])
        api = tweepy.API(auth)
        return api
    except:
        print("Problems with config.json")
        return None

# %%
def get_woeid(api, locations):
    twitter_world = api.trends_available()
    places = {loc['name'].lower() : loc['woeid'] for loc in twitter_world};
    woeids = []
    for location in locations:
        if location in places:
            woeids.append(places[location])
        else:
            print("err: ",location," woeid does not exist in trending topics")
    return woeids

# %%
def twitter_search(twitter_api, q, max_results=200, **kw):
    # See https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
    # and https://developer.twitter.com/en/docs/tweets/search/guides/standard-operators
    # for details on advanced search criteria that may be useful for 
    # keyword arguments
    
    # See https://dev.twitter.com/docs/api/1.1/get/search/tweets    
    search_results = twitter_api.search.tweets(q=q, count=100, **kw)
    
    statuses = search_results['statuses']
    
    # Iterate through batches of results by following the cursor until we
    # reach the desired number of results, keeping in mind that OAuth users
    # can "only" make 180 search queries per 15-minute interval. See
    # https://developer.twitter.com/en/docs/basics/rate-limits
    # for details. A reasonable number of results is ~1000, although
    # that number of results may not exist for all queries.
    
    # Enforce a reasonable limit
    max_results = min(1000, max_results)
    
    for _ in range(10): # 10*100 = 1000
        try:
            next_results = search_results['search_metadata']['next_results']
        except KeyError as e: # No more results when next_results doesn't exist
            break
            
        # Create a dictionary from next_results, which has the following form:
        # ?max_id=313519052523986943&q=NCAA&include_entities=1
        kwargs = dict([ kv.split('=') 
                        for kv in next_results[1:].split("&") ])
        
        search_results = twitter_api.search.tweets(**kwargs)
        statuses += search_results['statuses']
        
        if len(statuses) > max_results: 
            break
            
    return statuses
q = "#WirMachenAuf"
results = twitter_search(twitter_api, q, max_results=10)
        
# Show one sample search result by slicing the list...
print(json.dumps(results[0]['text'], indent=1))
print(json.dumps(results[0]['user']['name'], indent=1))
print(json.dumps(results[0]['user']['location'], indent=1))
